# %% [markdown]
# <a href="https://colab.research.google.com/github/elaisemsunny/poyinomial-regression-using-ridge-and-lasso/blob/main/Untitled32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#RIDGE AND LASSO
from google.colab import drive
drive.mount('/content/gdrive')
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline


from sklearn import model_selection
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

plt.style.use('bmh')
df=pd.read_csv('gdrive/My Drive/colab/groundwatercsv.csv',encoding= 'unicode_escape')
df.head()
# Out:
# Mounted at /content/gdrive
#    S.no.  ... Stage of Ground Water Extraction (%)
# 0      1  ...                                88.96
# 1      2  ...                                58.92
# 2      3  ...                                21.17
# 3      4  ...                                38.57
# 4      5  ...                                68.68
#
# [5 rows x 16 columns]

# %%
plt.style.use('bmh')
df=pd.read_csv('gdrive/My Drive/colab/groundwatercsv.csv',encoding= 'unicode_escape')
df.head()


import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
df.isnull().any()
df = df.fillna(method='ffill')


print(df['Annual Extractable Ground Water Resource'].describe())
list(set(df.dtypes.tolist()))
df1 = df.select_dtypes(include = ['float64', 'int64'])
df1.head()
# Out:
# count       689.000000
# mean      57420.749245
# std       47906.522769
# min           0.000000
# 25%       22991.490000
# 50%       46636.000000
# 75%       80235.380000
# max      328863.500000
# Name: Annual Extractable Ground Water Resource, dtype: float64
#    S.no.  ...  Stage of Ground Water Extraction (%)
# 0      1  ...                                 88.96
# 1      2  ...                                 58.92
# 2      3  ...                                 21.17
# 3      4  ...                                 38.57
# 4      5  ...                                 68.68
#
# [5 rows x 14 columns]

# %%
# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Recharge from rainfall During Monsoon Season', inplace = True)
ax.barh(df['Name of State'], df['Recharge from rainfall During Monsoon Season']) 
plt.title("Recharge from rainfall During Monsoon Season") 
# Show Plot 
plt.show() 

df3=df[df['Name of State'] =='SIKKIM' ]

# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df3.sort_values('Recharge from rainfall During Monsoon Season', inplace = True)
ax.barh(df3['Name of District'], df3['Recharge from rainfall During Monsoon Season']) 
plt.title("Recharge from rainfall During Monsoon Season") 
# Show Plot 
plt.show() 


# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Recharge from other sources During Monsoon Season', inplace = True)
ax.barh(df['Name of State'], df['Recharge from other sources During Monsoon Season']) 
plt.title("Recharge from other sources During Monsoon Season") 
# Show Plot 
plt.show() 

df4=df[df['Name of State'] =='PUNJAB' ]

# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df4.sort_values('Recharge from other sources During Monsoon Season', inplace = True)
ax.barh(df4['Name of District'], df4['Recharge from other sources During Monsoon Season']) 
plt.title("Recharge from other sources During Monsoon Season") 
# Show Plot 
plt.show() 


# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Recharge from rainfall During Non Monsoon Season', inplace = True)
ax.barh(df['Name of State'], df['Recharge from rainfall During Non Monsoon Season']) 
plt.title("Recharge from rainfall During Non Monsoon Season") 
# Show Plot 
plt.show() 

df5=df[df['Name of State'] =='WEST BENGAL' ]

# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df5.sort_values('Recharge from rainfall During Non Monsoon Season', inplace = True)
ax.barh(df5['Name of District'], df5['Recharge from rainfall During Non Monsoon Season']) 
plt.title("Recharge from rainfall During Non Monsoon Season") 
# Show Plot 
plt.show() 


# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Total Annual Ground Water Recharge', inplace = True)
ax.barh(df['Name of State'], df['Total Annual Ground Water Recharge']) 
plt.title("Total Annual Ground Water Rechargen") 
# Show Plot 
plt.show() 

df6=df[df['Name of State'] =='SIKKIM' ]

# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df6.sort_values('Total Annual Ground Water Recharge', inplace = True)
ax.barh(df6['Name of District'], df6['Total Annual Ground Water Recharge']) 
plt.title("Total Annual Ground Water Rechargen") 
# Show Plot 
plt.show() 


# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Total Natural Discharges', inplace = True)
ax.barh(df['Name of State'], df['Total Natural Discharges']) 
plt.title("Total Natural Discharges") 
# Show Plot 
plt.show() 

df7=df[df['Name of State'] =='SIKKIM' ]

# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df7.sort_values('Total Natural Discharges', inplace = True)
ax.barh(df7['Name of District'], df7['Total Natural Discharges']) 
plt.title("Total Natural Discharges") 
# Show Plot 
plt.show()


# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Annual Extractable Ground Water Resource', inplace = True)
ax.barh(df['Name of State'], df['Annual Extractable Ground Water Resource']) 
plt.title("Annual Extractable Ground Water Resource") 
# Show Plot 
plt.show() 

df8=df[df['Name of State'] =='WEST BENGAL' ]

# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df8.sort_values('Annual Extractable Ground Water Resource', inplace = True)
ax.barh(df8['Name of District'], df8['Annual Extractable Ground Water Resource']) 
plt.title("Annual Extractable Ground Water Resource") 
# Show Plot 
plt.show() 


# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Current Annual Ground Water Extraction For Irrigation', inplace = True)
ax.barh(df['Name of State'], df['Current Annual Ground Water Extraction For Irrigation']) 
plt.title("Current Annual Ground Water Extraction For Irrigation") 
# Show Plot 
plt.show() 

df9=df[df['Name of State'] =='PUNJAB' ]

# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df9.sort_values('Current Annual Ground Water Extraction For Irrigation', inplace = True)
ax.barh(df9['Name of District'], df9['Current Annual Ground Water Extraction For Irrigation']) 
plt.title("Current Annual Ground Water Extraction For Irrigation") 
# Show Plot 
plt.show() 


# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Current Annual Ground Water Extraction For Domestic & Industrial Use', inplace = True)
ax.barh(df['Name of State'], df['Current Annual Ground Water Extraction For Domestic & Industrial Use']) 
plt.title("Current Annual Ground Water Extraction For Domestic & Industrial Use") 
# Show Plot 
plt.show()

df10=df[df['Name of State'] =='TAMILNADU' ]

# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df10.sort_values('Current Annual Ground Water Extraction For Domestic & Industrial Use', inplace = True)
ax.barh(df10['Name of District'], df10['Current Annual Ground Water Extraction For Domestic & Industrial Use']) 
plt.title("Current Annual Ground Water Extraction For Domestic & Industrial Use") 
# Show Plot 
plt.show()


# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Total Current Annual Ground Water Extraction', inplace = True)
ax.barh(df['Name of State'], df['Total Current Annual Ground Water Extraction']) 
plt.title("Total Current Annual Ground Water Extraction") 
# Show Plot 
plt.show()

df11=df[df['Name of State'] =='PUNJAB' ]

# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df11.sort_values('Total Current Annual Ground Water Extraction', inplace = True)
ax.barh(df11['Name of District'], df11['Total Current Annual Ground Water Extraction']) 
plt.title("Total Current Annual Ground Water Extraction") 
# Show Plot 
plt.show()


# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Annual GW Allocation for Domestic Use as on 2025', inplace = True)
ax.barh(df['Name of State'], df['Annual GW Allocation for Domestic Use as on 2025']) 
plt.title("Annual GW Allocation for Domestic Use as on 2025") 
# Show Plot 
plt.show()

df12=df[df['Name of State'] =='RAJASTHAN' ]

# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df12.sort_values('Annual GW Allocation for Domestic Use as on 2025', inplace = True)
ax.barh(df12['Name of District'], df12['Annual GW Allocation for Domestic Use as on 2025']) 
plt.title("Annual GW Allocation for Domestic Use as on 2025") 
# Show Plot 
plt.show()


# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Net Ground Water Availability for future use', inplace = True)
ax.barh(df['Name of State'], df['Net Ground Water Availability for future use']) 
plt.title("Net Ground Water Availability for future use") 
# Show Plot 
plt.show()

df13=df[df['Name of State'] =='WEST BENGAL' ]

# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df13.sort_values('Net Ground Water Availability for future use', inplace = True)
ax.barh(df13['Name of District'], df13['Net Ground Water Availability for future use']) 
plt.title("Net Ground Water Availability for future use") 
# Show Plot 
plt.show()


# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Stage of Ground Water Extraction (%)', inplace = True)
ax.barh(df['Name of State'], df['Stage of Ground Water Extraction (%)']) 
plt.title("Stage of Ground Water Extraction (%)") 
# Show Plot 
plt.show()

df14=df[df['Name of State'] =='HIMACHAL' ]

# Horizontal Bar Plot 
fig, ax = plt.subplots(figsize =(16, 9)) 
df.sort_values('Stage of Ground Water Extraction (%)', inplace = True)
ax.barh(df14['Name of District'], df14['Stage of Ground Water Extraction (%)']) 
plt.title("Stage of Ground Water Extraction (%)") 
# Show Plot 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 689 entries, 381 to 195
# Data columns (total 16 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   S.no.                                                                 689 non-null    int64
#  1   Name of State                                                         689 non-null    object
#  2   Name of District                                                      689 non-null    object
#  3   Recharge from rainfall During Monsoon Season                          689 non-null    float64
#  4   Recharge from other sources During Monsoon Season                     689 non-null    float64
#  5   Recharge from rainfall During Non Monsoon Season                      689 non-null    float64
# ...

# %%
print(df['Annual Extractable Ground Water Resource'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(df['Annual Extractable Ground Water Resource'], color='g', bins=100, hist_kws={'alpha': 0.7});
# Out:
# count       689.000000
# mean      57420.749245
# std       47906.522769
# min           0.000000
# 25%       22991.490000
# 50%       46636.000000
# 75%       80235.380000
# max      328863.500000
# Name: Annual Extractable Ground Water Resource, dtype: float64
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
list(set(df.dtypes.tolist()))
df1 = df.select_dtypes(include = ['float64', 'int64'])
df1.head()
df1.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
df_num_corr = df1.corr()['Annual Extractable Ground Water Resource'][:-7] # -1 because the latest row is Total_Protiens 
golden_features_list = df_num_corr[abs(df_num_corr) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with PH :\n{}".format(len(golden_features_list), golden_features_list))

for i in range(0, len(df1.columns), 5):
    sns.pairplot(data=df1,
                x_vars=df1.columns[i:i+5],
                y_vars=['Annual Extractable Ground Water Resource'])
# Out:
# There is 5 strongly correlated values with PH :
# Total Annual Ground Water Recharge                       0.975900
# Recharge from rainfall During Monsoon Season             0.834111
# Recharge from other sources During Non Monsoon Season    0.748027
# Recharge from other sources During Monsoon Season        0.569726
# Recharge from rainfall During Non Monsoon Season         0.516435
# Name: Annual Extractable Ground Water Resource, dtype: float64
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)
# ...

# %%
import operator

individual_features_df = []
for i in range(0, len(df1.columns) - 7): # -6 because the last column is SalePrice
    tmpDf = df1[[df1.columns[i], 'Annual Extractable Ground Water Resource']]
    tmpDf = tmpDf[tmpDf[df1.columns[i]] != 0]
    individual_features_df.append(tmpDf)


all_correlations = {feature.columns[0]: feature.corr()['Annual Extractable Ground Water Resource'][0] for feature in individual_features_df}
all_correlations = sorted(all_correlations.items(), key=operator.itemgetter(1))
for (key, value) in all_correlations:
    print("{:>15}: {:>15}".format(key, value))

golden_features_list = [key for key, value in all_correlations if abs(value) >= 0.5]
print("There is {} strongly correlated values with PH:\n{}".format(len(golden_features_list), golden_features_list))    

corr = df1.drop('Annual Extractable Ground Water Resource', axis=1).corr() # We already examined PH correlations
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.1) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);
# Out:
#           S.no.: 0.05536655728923132
# Total Natural Discharges: 0.314137865300795
# Recharge from other sources During Monsoon Season: 0.5582671384929604
# Recharge from rainfall During Non Monsoon Season: 0.5707993030255237
# Recharge from other sources During Non Monsoon Season: 0.7381563156510462
# Recharge from rainfall During Monsoon Season: 0.832865197748351
# Total Annual Ground Water Recharge: 0.9756972845895366
# There is 5 strongly correlated values with PH:
# ['Recharge from other sources During Monsoon Season', 'Recharge from rainfall During Non Monsoon Season', 'Recharge from other sources During Non Monsoon Season', 'Recharge from rainfall During Monsoon Season', 'Total Annual Ground Water Recharge']

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split 
X = df1['Recharge from rainfall During Monsoon Season'].values.reshape(-1,1)
y = df1['Annual Extractable Ground Water Resource'].values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

from sklearn.preprocessing import PolynomialFeatures

def create_polynomial_regression_model(degree):
  "Creates a polynomial regression model for the given degree"


poly_features = PolynomialFeatures(degree=3)
  
  # transforms the existing features to higher degree features.
X_train_poly = poly_features.fit_transform(X_train)
  
  # fit the transformed features to Linear Regression
poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)
  
  # predicting on training data-set
y_train_predicted = poly_model.predict(X_train_poly)
  
  # predicting on test data-set
y_test_predict = poly_model.predict(poly_features.fit_transform(X_test))
  
  # evaluating the model on training dataset
rmse_train = np.sqrt(metrics.mean_squared_error(y_train, y_train_predicted))
r2_train = metrics.r2_score(y_train, y_train_predicted)
  
  # evaluating the model on test dataset
rmse_test = np.sqrt(metrics.mean_squared_error(y_test, y_test_predict))
r2_test = metrics.r2_score(y_test, y_test_predict)


print("The model performance for the training set")
print("-------------------------------------------")
print("RMSE of training set is {}".format(rmse_train))
print("R2 score of training set is {}".format(r2_train))
  
print("\n")
  
print("The model performance for the test set")
print("-------------------------------------------")
print("RMSE of test set is {}".format(rmse_test))
print("R2 score of test set is {}".format(r2_test))
    
print("\n\n")
plt.scatter(X_test, y_test) 
plt.plot([min(X_test), max(X_test)], [min(y_test_predict), max(y_test_predict)], color='red')  # regression line
plt.show()
# Out:
# The model performance for the training set
# -------------------------------------------
# RMSE of training set is 22256.353535187565
# R2 score of training set is 0.7651454302151364
#
#
# The model performance for the test set
# -------------------------------------------
# RMSE of test set is 26322.10069216682
# R2 score of test set is 0.7662084148044102

# %%
##ridge
print("ridge regression")
print("\n")
print("train data")

rr = Ridge(alpha=0.01)
rr.fit(X_train, y_train) 
pred_train_rr= rr.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train_rr)))
print(r2_score(y_train, pred_train_rr))
print("\n")

print("test data")
print("\n")

pred_test_rr= rr.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred_test_rr))) 
print(r2_score(y_test, pred_test_rr))
print("\n")
print("\n")
# Out:
# ridge regression
#
#
# train data
# 26133.056631538053
# 0.6762040505593531
#
#
# test data
#
#
# 27791.632226818994
# 0.739375108558647

# %%
print(rr.predict([[89200]]))
# Out:
# [[115969.88906557]]

# %%
##lasso
print("lasso regression")
print("\n")
print("train data")

model_lasso = Lasso(alpha=0.01)
model_lasso.fit(X_train, y_train) 
pred_train_lasso= model_lasso.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train_lasso)))
print(r2_score(y_train, pred_train_lasso))
print("\n")

print("test data")
print("\n")

pred_test_lasso= model_lasso.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred_test_lasso))) 
print(r2_score(y_test, pred_test_lasso))

print(poly_model.predict(poly_features.fit_transform([[89200]])))
# Out:
# lasso regression
#
#
# train data
# 26133.056631538053
# 0.6762040505593531
#
#
# test data
#
#
# 27791.632226914204
# 0.7393751085568612
# [[130106.14805297]]

# %%
print(model_lasso.predict([[89200]]))
# Out:
# [115969.88906509]
